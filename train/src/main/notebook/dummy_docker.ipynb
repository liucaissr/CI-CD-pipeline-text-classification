# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

import os
from pathlib import Path
dirpath = os.getcwd()
projectPath = str(Path(dirpath).parent)

# %%
print("hallo docker")
# Out:
# hallo gfaggle

# %%
print(dirpath+'/requirements.txt')
# Out:
# /Users/cai.liu/Documents/projects/Mday_1024/gfaggle/big.csv

# %%
import os 
os.listdir()
# Out:
# ['mlnotebook',
#  'docker-compose.yaml',
#  '.DS_Store',
#  'test_hdfs_download.ipynb',
#  'hallo_gfaggle.ipynb',
#  'requirements.txt',
#  'Dockerfile',
#  'mldata',
#  'README.md',
#  'test_pre_commit.ipynb',
#  'Jenkinsfile',
#  '.ipynb_checkpoints',
#  'convert.sh',
#  'httpfs',
#  '.git',
#  'data',
#  'hallo_gfaggle_hdfs.ipynb']

# %%
df = pd.read_csv(projectPath+'/data/big.csv')
df.head(10)
# Out:
#    wmdGensim     wmd4j          diff  \
# 0  0.011954   0.011954 -2.645848e-08
# 1  0.025317   0.025317 -1.970178e-09
# 2  0.033635   0.033633 -2.003997e-06
# 3  0.042440   0.042445  5.296898e-06
# 4  0.045238   0.045238 -7.008283e-16
# 5  0.053969   0.053971  2.647185e-06
# 6  0.064067   0.064067  7.992197e-09
# 7  0.078361   0.078361  7.632783e-16
# 8  0.102981   0.102979 -2.475572e-06
# 9  0.119273   0.123902  4.628643e-03
#
#                                                      test_title  \
# 0  kann man die pubertät stoppen ?
# 1  iphone zurückstellen ohne existierende apple id ?
# 2  ist anspucken eine straftat oder nicht ?
# 3  schickes turniershirt fürs reiten ?
# 4  pille möglicherweise doppelt genommen , wirkt sie trotzdem ?
# 5  dringend hilfe - uni ?
# 6  weiß jemand vielleicht wo ich diese jacke kaufen kann ?
# 7  wie lädt man save states beim epsxe emulator ?
# 8  pillen schutz gegeben ?
# 9  air max 90 von outfitter echt ?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          test_body  \
# 0  ich weiss . . . ich hab diese frage bereits schon mal gestellt , aber keine vernünftigen antworten bekommen . . . bitte nehmt dass , was ich schreibe zu 100% ernst , und antwortet nichts leichtsinniges wie :  , , ach dein gehirn wird sich verändern , ,  <strong> nein </strong> , ich bin mir hundertprozentig sicher ! !  ich bin ein junge . momentan bin ich 13 jahre alt , und werde in 3 monaten 14 . wie ihr bereits gelesen habt , will ich die pubertät verhindern . und <strong> nein </strong> ich bin keine transe ! ich möchte mein kindliches aussehen und meine hohe , schöne stimme behalten . außerdem beunruhigt es mich , dass man mit 14 schon s*x haben darf , denn ich finde das extrem ekelhaft . was natürlich absolut <strong> nicht </strong> heißt , dass ich mädchen eklig finde . ich war sogar schon in der fünften klasse in ein mädchen ein wenig verliebt . ich stehe auch nur auf mädchen die 12-13 jahre maximal noch anfang 14 jahre alt sind . mädchen die älter sind , finde ich schon beinahe hässlich . und ich bin mir ziemlich sicher , dass sich das nicht ändert . und ich will deswegen später nicht als pädo bezeichnet werden . ) : ich mache mir schon seit monaten deswegen extreme sorgen , und bin sehr traurig !  ) :  bitte helft mir und schreibt etwas , was mir <strong> <u> wirklich </u> </strong> hilft !  <strong> <u> bitte respektiert mich ! </u> </strong>
# 1  hey , ich habe meine apple id ohne mich vorher abzumelden gelöscht🙄 . nun möchte ich mein iphone komplett zurücksetzen doch da steht dann das ich das passwort für meine apple id eingeben muss . ich hab versucht mein altes passwort für meine gelöschte id einzugeben doch dann steht dort nur das diese apple id nicht mehr existiert . wäre sehr lieb wenn mir jemand dabei helfen könnte . 🙂 lg
# 2  " wie würdet ihr reagieren , wenn euch jemand anspuckt ? das ist mir gestern abend am bahnhof passiert . ein betrunkener , den ich bat , platz zu machen , schimpfte und spuckte mich am ende an . ich habe immer noch dieses ekelgefühl und wurde noch nie so erniedrigt . als es passierte , war ich geschockt und habe nicht reagiert . jetzt bereue ich es . anspucken ist an sich keine straftat , oder ? man ist ja nicht körperlich verletzt und die spucke hab ich mir natürlich aus dem gesicht gewischt und mich daheim mehrfach gewaschen wegen dem ekelgefühl . aber es ist doch trotzdem irgendwie eine "" verletzung "" . eine anzeige wird sich wahrscheinlich gar nicht lohnen . . . aber ich würde trotzdem gern eure meinung dazu hören . wie kriegt man dieses gefühl wieder weg ? wie würdet ihr damit umgehen ? einfach vergessen kann ich es nicht . "
# 3  hiii ,  ich bin zur zeit auf der suche nach einem schicken turniershirt fürs reiten .  es sollte weiß sein und man sollte die knöpfe vorne sehen ( also das da kein stoffstück drüber ist und auch kein reisverschluss ) . außerdem sollte es nicht allzu teuer sein und neben den knöpfen sollten keine rüschen sein . die knopfe dürfen aber gerne glitzern , ist aber nicht wichtig .  das shirt kann natürlich nicht all meine wünsche erfüllen , aber ich denke , dass es villeicht ein ähnliches gibt und ich es nur noch nicht gefunden habe .  lg und danke im vorraus
# 4  ich bin mir nicht sicher aber als ich die pille einnehmen wollte , ist es mir vielleicht ins getränk gefallen und zur sicherheit habe ich eine zweite genommen , wirkt sie trotzdem , die pille ?
# 5  hallo leute und zwar hab ich ein dringendes problem . ich hab mich für die uni beworben und ich hab gestern abend bemerkt das ich versehentlich bei meiner mathe punktzahl anstatt 2 punkte , 3 punkte angegeben habe . alle anderen angaben sind natürlich richtig . erwähnenswert ist , dass sich mein schnitt natürlich auch nicht ändert . es ist alles gleich geblieben außer halt dieser blöde punkt . hat dieser punkt nun irgendwelche auswirkungen und wird mir wegen so einem kleinem fehler nun der platz weggenommen ? ? ! dieser fehler macht mich nämlich so verrückt , da dieser studienplatz mir unglaublich wichtig ist . außerdem sind nun alle anderen bewerbungen durch die zulassung ungültig bzw sind somit ausgeschieden . ich hab so unglaublich angst , da ich bald mein zeugnis erreichen muss und es möglicherweise auffallen könnte . ist irgendjemandem so etwas ähnliches schon mal passiert ? kann mir jemand helfen ? ich bin jedem für einen rat dankbar 🙏🏻❤️
# 6  " hallo ich habe diese jacke jetzt auf einem konzert bei einen künster gesehen und finde die total genial . hat jemand ne ahnung wo ich die her bekomme ?   <x-gf-img-placeholder data-image-id= "" 11934186 "" > </x-gf-img-placeholder>   "
# 7  ich möchte auf dem epsxe emulator crash bandicoot spielen . ich hatte allerdings gemerkt dass das spiel ziemlich schwer ist . wenn man game over geht wird man ein oder mehrere level zurückgeschickt . das find ' ich beschissen . deshalb wollte ich vor jedem level ein save state setzen , und nach einen game over laden , aber es geht nicht . ich drücke f1 zum speichern , und f3 zum laden und es passiert nichts . . .  könnt ihr mir helfen . . . xd
# 8  hallo , ich bin in der 3 . pillenwoche und hab am mittwoch aus stress ausversehen 2 pillen geschluckt und habe bis heute schmierblutungen in meiner packungsbeilage steht , dass „überdosierung “ geringfügige vaginale blutungen auftreten können . bin ich geschützt wenn ich vor 8 tagen also ( freitag in der 2 . einnahmewoche ) gv hatte ? ich bin dankbar für jede antwort
# 3  hiii ,  ich bin zur zeit auf der suche nach einem schicken turniershirt fürs reiten .  es sollte weiß sein und man sollte die knöpfe vorne sehen ( also das da kein stoffstück drüber ist und auch kein reisverschluss ) . außerdem sollte es nicht allzu teuer sein und neben den knöpfen sollten keine rüschen sein . die knopfe dürfen aber gerne glitzern , ist aber nicht wichtig .  das shirt kann natürlich nicht all meine wünsche erfüllen , aber ich denke , dass es villeicht ein ähnliches gibt und ich es nur noch nicht gefunden habe .  lg und danke im vorraus
# 4  ich bin mir nicht sicher aber als ich die pille einnehmen wollte , ist es mir vielleicht ins getränk gefallen und zur sicherheit habe ich eine zweite genommen , wirkt sie trotzdem , die pille ?
# 5  hallo leute und zwar hab ich ein dringendes problem . ich hab mich für die uni beworben und ich hab gestern abend bemerkt das ich versehentlich bei meiner mathe punktzahl anstatt 2 punkte , 3 punkte angegeben habe . alle anderen angaben sind natürlich richtig . erwähnenswert ist , dass sich mein schnitt natürlich auch nicht ändert . es ist alles gleich geblieben außer halt dieser blöde punkt . hat dieser punkt nun irgendwelche auswirkungen und wird mir wegen so einem kleinem fehler nun der platz weggenommen ? ? ! dieser fehler macht mich nämlich so verrückt , da dieser studienplatz mir unglaublich wichtig ist . außerdem sind nun alle anderen bewerbungen durch die zulassung ungültig bzw sind somit ausgeschieden . ich hab so unglaublich angst , da ich bald mein zeugnis erreichen muss und es möglicherweise auffallen könnte . ist irgendjemandem so etwas ähnliches schon mal passiert ? kann mir jemand helfen ? ich bin jedem für einen rat dankbar 🙏🏻❤️
# 6  " hallo ich habe diese jacke jetzt auf einem konzert bei einen künster gesehen und finde die total genial . hat jemand ne ahnung wo ich die her bekomme ?   <x-gf-img-placeholder data-image-id= "" 11929736 "" > </x-gf-img-placeholder>   "
# 7  ich möchte auf dem epsxe emulator crash bandicoot spielen . ich hatte allerdings gemerkt dass das spiel relativ schwer ist . wenn man game over geht wird man ein oder mehrere level zurückgeschickt . das find ' ich beschissen . deshalb wollte ich vor jedem level ein save state setzen , und nach einen game over laden , aber es geht nicht . ich drücke f1 zum speichern , und f3 zum laden und es passiert nichts . . .  könnt ihr mir helfen . . . xd
# 8  hallo , ich bin in der 3 . pillenwoche und hab am mittwoch aus stress ausversehen 2 pillen geschluckt und habe bis heute schmierblutungen in meiner packungsbeilage steht , dass „überdosierung “ geringfügige vaginale blutungen auftreten können . bin ich geschützt wenn ich vor 8 tagen also ( freitag in der 2 . einnahmewoche ) gv hatte ? ich bin dankbar für jede antwort
# 9  " hallo ,  ich habe mir bei outfitter . de neue air max 90 essential in weiß geholt . leider weiß ich nicht ob diese echt sind . mir ist aufgefallen , dass das innenetikett ( siehe bild ) der schuhe etwas anders aussieht als die meiner anderen nike sneaker und die innensohle ist unten blau . die box hat auch ein anderes etikett als die meiner anderen schuhe . könnt ihr erkennen ob diese schuhe fake sind ?  danke im voraus radu   <x-gf-img-placeholder data-image-id= "" 12028262 "" > </x-gf-img-placeholder>    <x-gf-img-placeholder data-image-id= "" 12028267 "" > </x-gf-img-placeholder>    <x-gf-img-placeholder data-image-id= "" 12028272 "" > </x-gf-img-placeholder>   "
#
#    label   test_id  other_id   user_id
# 0  1      85124598  85124523  23228511
# 1  1      85674356  85674791  23847006
# 2  1      85270458  85270449  23278824
# 3  1      86961889  86961813  20494452
# 4  0      83479500  83479385  22944145
# 5  1      88191572  88155592  13163170
# 6  1      86872496  86850546  24367226
# 7  0      84912741  84912387  23228511
# 8  1      84431119  84431614  22944145
# 9  1      87292562  87292467  20275367

# %%
df.to_csv(dirpath+'/output_from_notebook.csv')
